# %%
import caption_it
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as imp

# %%
image=imp.imread("girl_test.jpg")
plt.imshow(image)
plt.show()

# %%
caption_it.final_caption('girl_test.jpg')
# Out:
# 'little girl in pink shirt is running through the grass'

# %%
image=imp.imread("train_test.jpg")
plt.imshow(image)
plt.show()

# %%
caption_it.final_caption('train_test.jpg')
# Out:
# 'white dog is running on the street'

# %%
path='./static/{}'.format('man_running_test.jpg')

# %%
path
# Out:
# './static/man_running_test.jpg'

# %%
caption_it.final_caption(path)
# Out:
# 'man in blue shirt is standing on the beach'
